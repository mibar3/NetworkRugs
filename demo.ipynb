# %% [markdown]
# ## Demo of NetworkRug Visualizer
#
# Bachelor Thesis Friederike

# %%
# Launches Data Generator and posteriorly Network Visualizer
import ba_utils.interface as interface
interface.start_gui()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Launches Data Generator and posteriorly Network Visualizer
#       2 import ba_utils.interface as interface
# ----> 3 interface.start_gui()
#
# File ~/NetworkRugs/ba_utils/interface.py:541, in start_gui()
#     539 def start_gui():
#     540     global graphs_data
# --> 541     root = tk.Tk()
#     542     root.title("NetworkRug Data Generator")
#     543     root.geometry("820x1600")
#
# File /usr/lib64/python3.12/tkinter/__init__.py:2346, in Tk.__init__(self, screenName, baseName, className, useTk, sync, use)
#    2344         baseName = baseName + ext
#    2345 interactive = False
# -> 2346 self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2347 if _debug:
#    2348     self.tk.settrace(_print_command)
#
# ...

# %%
# Launches Networ Visualizer directly with contact pattterns data
import ba_utils.interface_real_data as interface
interface.start_gui()

# %%
from ba_utils.load_real_data import load_real_graphs
g = load_real_graphs()
print(len(g))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ba_utils.load_real_data import load_real_graphs
#       2 g = load_real_graphs()
#       3 print(len(g))
#
# ImportError: cannot import name 'load_real_graphs' from 'ba_utils.load_real_data' (/home/scc/miranda.barros-everett/NetworkRugs/ba_utils/load_real_data.py)
